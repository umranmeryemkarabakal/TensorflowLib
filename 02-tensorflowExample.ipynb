# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")
dataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
dataFrame.head()
#mpg kilometrede ne kadar yakıyor
#engineSize motor boyutu
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\umk54\AppData\Local\Temp\ipykernel_18256\686912093.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataFrame["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
#sbn.countplot(dataFrame["year"])

# %%
numeric_df = dataFrame.select_dtypes(include=[np.number])

# %%
numeric_df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
correlation = numeric_df.corr()["price"].sort_values()
correlation
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(data=dataFrame, x = "mileage", y = "price")
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending = False)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# ...     ...     ...          ...      ...  ...   ...         ...
# 11549  2002    1495    Automatic    13800  305  39.8         2.7
# 12594  2004    1495       Manual   119000  300  34.5         1.8
# 11765  2000    1490    Automatic    87000  265  27.2         3.2
# 12008  2010    1350       Manual   116126  145  54.3         2.0
# 11816  2003     650       Manual   109090  235  40.0         1.4
#
# [13119 rows x 7 columns]

# %%
dataFrame.sort_values("price",ascending = True)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 11816  2003     650       Manual   109090  235  40.0         1.4
# 12008  2010    1350       Manual   116126  145  54.3         2.0
# 11765  2000    1490    Automatic    87000  265  27.2         3.2
# 11549  2002    1495    Automatic    13800  305  39.8         2.7
# 12594  2004    1495       Manual   119000  300  34.5         1.8
# ...     ...     ...          ...      ...  ...   ...         ...
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
#
# [13119 rows x 7 columns]

# %%
dataFrame.sort_values("price",ascending = False).head(20)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
len(dataFrame) * 0.01
# Out:
# 131.19

# %%
yuzdeDoksanDokuzDataFrame = dataFrame.sort_values("price",ascending=False).iloc[131:] #indexe göre yerini bul

# %%
yuzdeDoksanDokuzDataFrame = yuzdeDoksanDokuzDataFrame.select_dtypes(include=[np.number])

# %%
yuzdeDoksanDokuzDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize = (7,5))
sbn.displot(yuzdeDoksanDokuzDataFrame)

# %%
numeric_df.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
yuzdeDoksanDokuzDataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
numeric_df[numeric_df.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame = yuzdeDoksanDokuzDataFrame

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame = dataFrame[dataFrame.year != 1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y = numeric_df["price"].values
x = numeric_df.drop("price",axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9183

# %%
len(x_test)
# Out:
# 3936

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
import tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9183, 5)

# %%
model = Sequential()

# %%
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

# %%
model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,batch_size=250,validation_data=(x_test,y_test),epochs=300)
#validasyon doğrulama verisi
# Out:
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 737707968.0000 - val_loss: 769854720.0000
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 755685312.0000 - val_loss: 769750208.0000
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 742463872.0000 - val_loss: 769321792.0000
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 743870272.0000 - val_loss: 767884288.0000
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 722270976.0000 - val_loss: 763936832.0000
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 732498496.0000 - val_loss: 754793856.0000
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 727017792.0000 - val_loss: 736311360.0000
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 692331072.0000 - val_loss: 703062144.0000
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 672965824.0000 - val_loss: 648407552.0000
# Epoch 10/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  741836032.0  769854720.0
# 1  741783296.0  769750208.0
# 2  741558784.0  769321792.0
# 3  740735872.0  767884288.0
# 4  738274624.0  763936832.0

# %%
kayipVerisi.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
# Out:
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
tahminDizisi
# Out:
# array([[38442.156],
#        [29806.219],
#        [40813.54 ],
#        ...,
#        [23978.176],
#        [19381.574],
#        [21991.453]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)
# Out:
# 3742.891537705088

# %%
numeric_df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test,y_test,"g-*")

# %%
numeric_df
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2005   5200    63000  325  32.1         1.8
# 1      2017  34948    27000   20  61.4         2.1
# 2      2016  49948     6200  555  28.0         5.5
# 3      2016  61948    16000  325  30.4         4.0
# 4      2016  73948     4000  325  30.1         4.0
# ...     ...    ...      ...  ...   ...         ...
# 13114  2020  35999      500  145  55.4         2.0
# 13115  2020  24699     2500  145  55.4         2.0
# 13116  2019  30999    11612  145  41.5         2.1
# 13117  2019  37990     2426  145  45.6         2.0
# 13118  2019  54999     2075  145  52.3         2.9
#
# [13119 rows x 6 columns]

# %%
dataFrame
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12987 rows x 6 columns]

# %%
dataFrame.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
yeniArabaSeries = dataFrame.drop("price",axis=1).iloc[2]

# %%
type(yeniArabaSeries)
# Out:
# pandas.core.series.Series

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))

# %%
model.predict(yeniArabaSeries)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# array([[68265.79]], dtype=float32)
